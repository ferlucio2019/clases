# %% [markdown]
# # Infraestructura

# %% [markdown]
# ## Instalar Anaconda

# %% [markdown]
# ### Instalar Anaconda en Windows

# %%
from IPython.lib.display import YouTubeVideo
YouTubeVideo('YQu4OPmQ8Q0',width=800,height=400)

# %%
### Instalar Anaconda en Linux

# %%
YouTubeVideo('lu1wF_ncnpc',width=800,height=400)

# %% [markdown]
# ## Notebooks.ai

# %% [markdown]
# Notebooks.ai es un entrono en la nube para programar en python y orientado a la Ciencia de Datos

# %%
import IPython

from IPython.core.display import HTML,display
#HTML('<a href="http://example.com">link</a>')

#display(HTML('<a href="http://example.com">link</a>'))

from IPython.display import IFrame
#IFrame(src='http://notebooks.ai', width=900, height=600)
IPython.display.HTML(url='http://notebooks.ai')
# Out:
# <!DOCTYPE html><html lang="en" dir="ltr"><head><meta charSet="utf-8"/><meta content="IE=edge" http-equiv="X-UA-Compatible"/><meta name="viewport" content="user-scalable=0, initial-scale=1, minimum-scale=1, width=device-width, height=device-height"/><meta name="version" content="production"/><meta name="msapplication-TileColor" content="#3390FF"/><meta name="msapplication-TileImage" content="https://notebooks.ai/_next/static/images/ms-icon-144x144-e5306610.png"/><meta name="theme-color" content="#3390FF"/><link href="https://notebooks.ai" rel="canonical"/><link rel="icon" type="image/png" sizes="192x192" href="/_next/static/images/android-icon-192x192-2ab58f86.png"/><link rel="apple-touch-icon" sizes="57x57" href="/_next/static/images/apple-icon-57x57-c0a37b20.png"/><link rel="apple-touch-icon" sizes="60x60" href="/_next/static/images/apple-icon-60x60-fe60386b.png"/><link rel="apple-touch-icon" sizes="72x72" href="/_next/static/images/apple-icon-72x72-c713ef90.png"/><link rel="apple-t
# ...

# %% [markdown]
# # Docker

# %% [markdown]
# ## Que es docker

# %% [markdown]
# Me garantiza llevar un entorno de un sitio a otro y que funcione

# %%
YouTubeVideo('1LRzlUoyZg4',width=800,height=400)

# %% [markdown]
# ## Instalar docker en windows

# %%
YouTubeVideo('BK-C2RofmTE',width=800,height=400)

# %% [markdown]
# # Git

# %% [markdown]
# ## Que es Git

# %%
YouTubeVideo('HiXLkL42tMU',width=800,height=400)

# %% [markdown]
# # Bibliografía

# %%
IPython.display.HTML(url='https://github.com/grananqvist/Awesome-Quant-Machine-Learning-Trading.git')
# Out:
# <!DOCTYPE html>
# <html lang="en">
#   <head>
#     <meta charset="utf-8">
#   <link rel="dns-prefetch" href="https://github.githubassets.com">
#   <link rel="dns-prefetch" href="https://avatars0.githubusercontent.com">
#   <link rel="dns-prefetch" href="https://avatars1.githubusercontent.com">
#   <link rel="dns-prefetch" href="https://avatars2.githubusercontent.com">
#   <link rel="dns-prefetch" href="https://avatars3.githubusercontent.com">
#   <link rel="dns-prefetch" href="https://github-cloud.s3.amazonaws.com">
#   <link rel="dns-prefetch" href="https://user-images.githubusercontent.com/">
#
#
#
#   <link crossorigin="anonymous" media="all" integrity="sha512-YBhzjURrLT0ouaG+HHemxsJ+87lEDYGlXkaH7QjOkpaCqqorVOCwE6qJ8Wek2bhORLngfoUoqivhcDxi1XBAtw==" rel="stylesheet" href="https://github.githubassets.com/assets/frameworks-6018738d446b2d3d28b9a1be1c77a6c6.css" />
# ...
