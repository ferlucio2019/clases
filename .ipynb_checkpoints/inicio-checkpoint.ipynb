# %%
from IPython.lib.display import YouTubeVideo
import IPython

from IPython.core.display import HTML,display
#HTML('<a href="http://example.com">link</a>')

#display(HTML('<a href="http://example.com">link</a>'))

from IPython.display import IFrame

# %% [markdown]
# # Data Science
#
# Es poder extraer inteligencia de los datos suministrados.
#
# Esta inteligencia ha de ser tanto por su acierto como por su evolución a lo largo del tiempo

# %% [markdown]
# La ciencia de Datos la podemos dividir en tres empleos o funciones
#
#     - Data Analyst: Presenta y ordena los datos
#     - Data Scientist: Realiza los cáculos para obtener inteligencia
#     - Data Engineering: Se encarga de la Infraestructura de los recursos y programas necesarios
#
# Lo primero que tenemos que hacer es crear la infraestructura para la obtención de inteligencia

# %%
YouTubeVideo('R2Kr2ELpwQI',width=800,height=400)

# %%
## Recursos para Data Emgineering

IPython.display.HTML(url='https://github.com/igorbarinov/awesome-data-engineering')
# Out:
# <!DOCTYPE html>
# <html lang="en">
#   <head>
#     <meta charset="utf-8">
#   <link rel="dns-prefetch" href="https://github.githubassets.com">
#   <link rel="dns-prefetch" href="https://avatars0.githubusercontent.com">
#   <link rel="dns-prefetch" href="https://avatars1.githubusercontent.com">
#   <link rel="dns-prefetch" href="https://avatars2.githubusercontent.com">
#   <link rel="dns-prefetch" href="https://avatars3.githubusercontent.com">
#   <link rel="dns-prefetch" href="https://github-cloud.s3.amazonaws.com">
#   <link rel="dns-prefetch" href="https://user-images.githubusercontent.com/">
#
#
#
#   <link crossorigin="anonymous" media="all" integrity="sha512-dxFVfmRlzgntw9xnKsYVxQUyV8JZifjI76hlssNAlbCn/gOmgfo4skfRATXTzQ8qG+NNgIh6fvkeQttpFQRpQQ==" rel="stylesheet" href="https://github.githubassets.com/assets/frameworks-7711557e6465ce09edc3dc672ac615c5.css" />
# ...

# %%
## Herramientas en real

# %%
YouTubeVideo('bl1XSZy11vQ',width=800,height=400)

#https://www.youtube.com/watch?v=bl1XSZy11vQ

# %% [markdown]
# # Infraestructura

# %% [markdown]
# ## Instalar Anaconda

# %% [markdown]
# ### Instalar Anaconda en Windows

# %%
YouTubeVideo('YQu4OPmQ8Q0',width=800,height=400)

# %% [markdown]
# ### Instalar Anaconda en Linux

# %%
YouTubeVideo('lu1wF_ncnpc',width=800,height=400)

# %% [markdown]
# ## Notebooks.ai

# %% [markdown]
# Notebooks.ai es un entrono en la nube para programar en python y orientado a la Ciencia de Datos

# %%
#IFrame(src='http://notebooks.ai', width=900, height=600)
IPython.display.HTML(url='http://notebooks.ai')
# Out:
# <!DOCTYPE html><html lang="en" dir="ltr"><head><meta charSet="utf-8"/><meta content="IE=edge" http-equiv="X-UA-Compatible"/><meta name="viewport" content="user-scalable=0, initial-scale=1, minimum-scale=1, width=device-width, height=device-height"/><meta name="version" content="production"/><meta name="msapplication-TileColor" content="#3390FF"/><meta name="msapplication-TileImage" content="https://notebooks.ai/_next/static/images/ms-icon-144x144-e5306610.png"/><meta name="theme-color" content="#3390FF"/><link href="https://notebooks.ai" rel="canonical"/><link rel="icon" type="image/png" sizes="192x192" href="/_next/static/images/android-icon-192x192-2ab58f86.png"/><link rel="apple-touch-icon" sizes="57x57" href="/_next/static/images/apple-icon-57x57-c0a37b20.png"/><link rel="apple-touch-icon" sizes="60x60" href="/_next/static/images/apple-icon-60x60-fe60386b.png"/><link rel="apple-touch-icon" sizes="72x72" href="/_next/static/images/apple-icon-72x72-c713ef90.png"/><link rel="apple-t
# ...

# %% [markdown]
# # Docker

# %% [markdown]
# ## Que es docker

# %% [markdown]
# Me garantiza llevar un entorno de un sitio a otro y que funcione

# %%
YouTubeVideo('1LRzlUoyZg4',width=800,height=400)

# %% [markdown]
# ## Instalar docker en windows

# %%
YouTubeVideo('BK-C2RofmTE',width=800,height=400)

# %% [markdown]
# # Git

# %% [markdown]
# ## Docker en la Nube
#
# Aparte de poder instalar docker en nuestra máquina podemos instalarlo en la nube ( AWS, Google Cloud, ....) o en ciertos servicios como
#
#
# PLAY-WITH-DOCKER
#
# Que nos permite aprender docker y ver ciertos desarrollos como data engineering. Os pongo un manual.

# %%
#https://training.play-with-docker.com/
IPython.display.HTML(url='https://training.play-with-docker.com/') 
#IPython.display.HTML(url='https://labs.play-with-docker.com/')
# Out:
# <!-- Remove the comments to compress html
#
# ---
# layout: compress
# ---
#
# -->
# <!DOCTYPE html>
# <html>
#
#   <head>
# <title>Play with Docker Classroom</title>
# <meta charset="utf-8">
# <meta http-equiv="X-UA-Compatible" content="IE=edge">
# <meta name="viewport" content="width=device-width, initial-scale=1">
#
# <meta name="twitter:card" content="summary_large_image" />
# <meta name="twitter:title" content="Play with Docker Classroom" />
# <meta name="twitter:description" content="Learn docker through online trainings in training.play-with-docker.com" />
# <meta name="twitter:image" content="https://training.play-with-docker.com/images/simple-logo.png" />
#
#
#
#
# <link href="//maxcdn.bootstrapcdn.com/bootstrap/3.3.7/css/bootstrap.min.css" rel="stylesheet">
# <link rel="stylesheet" type="text/css" href="//fonts.googleapis.com/css?family=Open+Sans" />
#
# <style>
#
# ...

# %% [markdown]
# ## Que es Git

# %%
YouTubeVideo('HiXLkL42tMU',width=800,height=400)

# %% [markdown]
# # Github
#
# Github es una forma eficiente de almacenar repositorios e interactúa con git

# %%
YouTubeVideo('ggD808TwCvU',width=800,height=400)


#https://www.youtube.com/watch?v=ggD808TwCvU

# %% [markdown]
# # Bibliografía

# %%
IPython.display.HTML(url='https://github.com/grananqvist/Awesome-Quant-Machine-Learning-Trading.git')
# Out:
# <!DOCTYPE html>
# <html lang="en">
#   <head>
#     <meta charset="utf-8">
#   <link rel="dns-prefetch" href="https://github.githubassets.com">
#   <link rel="dns-prefetch" href="https://avatars0.githubusercontent.com">
#   <link rel="dns-prefetch" href="https://avatars1.githubusercontent.com">
#   <link rel="dns-prefetch" href="https://avatars2.githubusercontent.com">
#   <link rel="dns-prefetch" href="https://avatars3.githubusercontent.com">
#   <link rel="dns-prefetch" href="https://github-cloud.s3.amazonaws.com">
#   <link rel="dns-prefetch" href="https://user-images.githubusercontent.com/">
#
#
#
#   <link crossorigin="anonymous" media="all" integrity="sha512-dxFVfmRlzgntw9xnKsYVxQUyV8JZifjI76hlssNAlbCn/gOmgfo4skfRATXTzQ8qG+NNgIh6fvkeQttpFQRpQQ==" rel="stylesheet" href="https://github.githubassets.com/assets/frameworks-7711557e6465ce09edc3dc672ac615c5.css" />
# ...

# %% [markdown]
# # Repositorio de libros

# %%
IPython.display.HTML(url='https://github.com/calelin/myBooks-1') 

#https://github.com/calelin/myBooks-1/tree/master/Books/AI
# Out:
# <!DOCTYPE html>
# <html lang="en">
#   <head>
#     <meta charset="utf-8">
#   <link rel="dns-prefetch" href="https://github.githubassets.com">
#   <link rel="dns-prefetch" href="https://avatars0.githubusercontent.com">
#   <link rel="dns-prefetch" href="https://avatars1.githubusercontent.com">
#   <link rel="dns-prefetch" href="https://avatars2.githubusercontent.com">
#   <link rel="dns-prefetch" href="https://avatars3.githubusercontent.com">
#   <link rel="dns-prefetch" href="https://github-cloud.s3.amazonaws.com">
#   <link rel="dns-prefetch" href="https://user-images.githubusercontent.com/">
#
#
#
#   <link crossorigin="anonymous" media="all" integrity="sha512-dxFVfmRlzgntw9xnKsYVxQUyV8JZifjI76hlssNAlbCn/gOmgfo4skfRATXTzQ8qG+NNgIh6fvkeQttpFQRpQQ==" rel="stylesheet" href="https://github.githubassets.com/assets/frameworks-7711557e6465ce09edc3dc672ac615c5.css" />
# ...

# %% [markdown]
# # Objetivos
#
# - Ver los diferentes empleos de la ciencia de Datos
# - Ver la Infraestructura de la Ciencia de Datos
# - Ejecutar python en el ordenador
# - Ejecutar python en la nube
# - Control de versiones
# - Crear Repositorios
